# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission, if necessary. Sections that begin with **'Implementation'** in the header indicate where you should begin your implementation for your project. Note that some sections of implementation are optional, and will be marked with **'Optional'** in the header.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle
import numpy as np

# TODO: Fill this in based on where you saved the training and testing data

training_file = "train_gray_blur_contrast_rot_final.p"
testing_file = "test_final_gray.p"
validation_file = "validation_gray_contrast.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
# with open(testing_file, mode='rb') as f:
#     test = pickle.load(f)
with open(validation_file, mode='rb') as f:
    validation = pickle.load(f)
    
X_train_old, y_train = train['features'], train['labels']
# X_test, y_test = test['features'], test['labels']
X_validation_old, y_validation = validation['features'], validation['labels']

# %%
np.shape(X_train_old)
# Out:
# (274463, 32, 32, 1)

# %%
from sklearn.preprocessing import normalize


X_new = X_train_old#.astype(float)
X_new = X_new.astype(float)
m = np.mean(X_train_old)
st = np.std(X_train_old)
X_new-=m
X_train = X_new /st

X_val = X_validation_old#.astype(float)
X_val = X_val.astype(float)
X_val-=m
X_validation = X_val /st

# X_test = X_test#.astype(float)
# X_test = X_test.astype(float)
# X_test-=128.0
# X_test = X_test /255.0

#print(X_train_new[0][0][0])
#print(type(X_train_new))
#print(X_train[0].astype(np.float32))

# %%
(203.-128.0)/128
# Out:
# 0.5859375

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 2D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below.

# %%
### Replace each question mark with the appropriate value.
import numpy as np

# TODO: Number of training examples
n_train = len(X_train)

# TODO: Number of testing examples.
n_test = len(X_val)

# TODO: What's the shape of an traffic sign image?
image_shape = np.shape(X_train[0])

# TODO: How many unique classes/labels there are in the dataset.
n_classes = len(set(y_train))

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 274463
# Number of testing examples = 4168
# Image data shape = (32, 32, 1)
# Number of classes = 43

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
### Data exploration visualization goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.
#
# **NOTE:** The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %% [markdown]
# #### LENet Code for traffic Sign classifier

# %%
### Preprocess the data here.
### Feel free to use as many code cells as needed.

from tensorflow.contrib.layers import flatten
import tensorflow as tf


def conv2d(x,weight,bias,strides=1,padding='SAME'):
    layer = tf.nn.conv2d(x,weight,[1,strides,strides,1],padding=padding)
    layer = tf.nn.bias_add(layer,bias)
    layer = tf.nn.relu(layer)
    return layer

def maxpool(x,k=2,padding='SAME'):
    kernel_size = [1,k,k,1]
    return tf.nn.max_pool(x,ksize=kernel_size,strides=[1,k,k,1],padding=padding)
    
    
def LeNet(x,keep_prob):    
    # Hyperparameters
    mu = 0
    sigma = 0.1
    layer_depth = {
    'layer_1': 6,
    'layer_2': 16,
    'fully_connected_1': 120,
    'fully_connected_2': 84,
    'fully_connected_3': 43
    }
    
    weights = {
        'layer_1': tf.Variable(tf.random_normal([5, 5, 1, layer_depth['layer_1']], mean=0.0, stddev=1.0, dtype=tf.float32) ),
        'layer_2': tf.Variable(tf.random_normal(
                [5, 5, layer_depth['layer_1'], layer_depth['layer_2']],mu,sigma,dtype=tf.float32)),
        'fully_connected_1':tf.Variable(tf.random_normal(
                [5*5*16, layer_depth['fully_connected_1']],mu,sigma,dtype=tf.float32)),
        'fully_connected_2':tf.Variable(tf.random_normal(
               [layer_depth['fully_connected_1'], layer_depth['fully_connected_2']],mu,sigma,dtype=tf.float32)),
        'fully_connected_3':tf.Variable(tf.random_normal(
                [layer_depth['fully_connected_2'], layer_depth['fully_connected_3']],mu,sigma,dtype=tf.float32))
    }
    biases = {
        'layer_1': tf.Variable(tf.zeros(
                layer_depth['layer_1'])),
        'layer_2': tf.Variable(tf.zeros(
                layer_depth['layer_2'])),
        'fully_connected_1':tf.Variable(tf.zeros( 
                layer_depth['fully_connected_1'])),
        'fully_connected_2':tf.Variable(tf.zeros( 
               layer_depth['fully_connected_2'])),
        'fully_connected_3':tf.Variable(tf.zeros( 
                layer_depth['fully_connected_3'])),
    }
    
    # TODO: Layer 1: Convolutional. Input = 32x32x3. Output = 28x28x6.
    # TODO: Activation.
    layer_1 = conv2d(x,weights['layer_1'],biases['layer_1'],strides=1,padding='VALID')
    print(layer_1.get_shape())
    # TODO: Pooling. Input = 28x28x6. Output = 14x14x6.
    layer_1 = maxpool(layer_1,k=2)
    print(layer_1.get_shape())
    
    
    # TODO: Layer 2: Convolutional. Output = 10x10x16.
    
    # TODO: Activation.
    layer_2 = conv2d(layer_1,weights['layer_2'],biases['layer_2'],strides=1,padding='VALID')
    print(layer_2.get_shape())
    # TODO: Pooling. Input = 10x10x16. Output = 5x5x16.
    layer_2 = maxpool(layer_2,k=2)
    print(layer_2.get_shape())
    
    
    # TODO: Flatten. Input = 5x5x16. Output = 400.
    fc1 = flatten(layer_2)
    
    
    fc1_drop = tf.nn.dropout(fc1, keep_prob)

    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.
    
    fc1 = tf.add(
        tf.matmul(fc1_drop, weights['fully_connected_1']),
        biases['fully_connected_1'])
    # TODO: Activation.
    fc1= tf.nn.tanh(fc1)
    
    
    fc1_drop = tf.nn.dropout(fc1, keep_prob)
    # TODO: Layer 4: Fully Connected. Input = 120. Output = 84.
    
    fc2 = tf.add(
        tf.matmul(fc1_drop, weights['fully_connected_2']),
        biases['fully_connected_2'])
    # TODO: Activation.
    fc2= tf.nn.tanh(fc2)
    fc2_drop = tf.nn.dropout(fc2, keep_prob)

    # TODO: Layer 5: Fully Connected. Input = 84. Output = 10.
    fc3 = tf.add(
        tf.matmul(fc2_drop, weights['fully_connected_3']),
        biases['fully_connected_3'])
    # TODO: Activation.
    logits= tf.nn.tanh(fc3)
    return logits

# %%
def LeNet_multi(x,keep_prob):    
    # Hyperparameters
    mu = 0
    sigma = 0.1
    layer_depth = {
    'layer_1': 9,
    'layer_2': 16,
    'fully_connected_1': 120,
#     'fully_connected_2': 84,
    'fully_connected_3': 43
    }
    
    weights = {
        'layer_1': tf.Variable(tf.random_normal([5, 5, 1, layer_depth['layer_1']], mean=0.0, stddev=1.0, dtype=tf.float32) ),
        'layer_2': tf.Variable(tf.random_normal(
                [5, 5, layer_depth['layer_1'], layer_depth['layer_2']],mu,sigma,dtype=tf.float32)),
        'fully_connected_1':tf.Variable(tf.random_normal(
                [5*5*16+14*14*9, layer_depth['fully_connected_1']],mu,sigma,dtype=tf.float32)),
#         'fully_connected_2':tf.Variable(tf.random_normal(
#                [layer_depth['fully_connected_1'], layer_depth['fully_connected_2']],mu,sigma,dtype=tf.float32)),
        'fully_connected_3':tf.Variable(tf.random_normal(
                [layer_depth['fully_connected_1'], layer_depth['fully_connected_3']],mu,sigma,dtype=tf.float32))
    }
    biases = {
        'layer_1': tf.Variable(tf.zeros(
                layer_depth['layer_1'])),
        'layer_2': tf.Variable(tf.zeros(
                layer_depth['layer_2'])),
        'fully_connected_1':tf.Variable(tf.zeros( 
                layer_depth['fully_connected_1'])),
#         'fully_connected_2':tf.Variable(tf.zeros( 
#                layer_depth['fully_connected_2'])),
        'fully_connected_3':tf.Variable(tf.zeros( 
                layer_depth['fully_connected_3'])),
    }
    
    # TODO: Layer 1: Convolutional. Input = 32x32x3. Output = 28x28x6.
    # TODO: Activation.
    layer_1 = conv2d(x,weights['layer_1'],biases['layer_1'],strides=1,padding='VALID')
    print(layer_1.get_shape())
    # TODO: Pooling. Input = 28x28x6. Output = 14x14x6.
    layer_1 = maxpool(layer_1,k=2)
    print(layer_1.get_shape())
    
    
    # TODO: Layer 2: Convolutional. Output = 10x10x16.
    
    # TODO: Activation.
    layer_2 = conv2d(layer_1,weights['layer_2'],biases['layer_2'],strides=1,padding='VALID')
    print(layer_2.get_shape())
    # TODO: Pooling. Input = 10x10x16. Output = 5x5x16.
    layer_2 = maxpool(layer_2,k=2)
    print(layer_2.get_shape())
    
    
    # TODO: Flatten. Input = 5x5x16. Output = 400.
    
    fc1 = flatten(layer_2)
    fc1 = tf.concat(1,(fc1,flatten(layer_1)))
    
    
    fc1_drop = tf.nn.dropout(fc1, keep_prob)

    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.
    
    fc1 = tf.add(
        tf.matmul(fc1_drop, weights['fully_connected_1']),
        biases['fully_connected_1'])
    # TODO: Activation.
    fc1= tf.nn.tanh(fc1)
    
    
    fc1_drop = tf.nn.dropout(fc1, keep_prob)
    # TODO: Layer 4: Fully Connected. Input = 120. Output = 84.
    
#     fc2 = tf.add(
#         tf.matmul(fc1_drop, weights['fully_connected_2']),
#         biases['fully_connected_2'])
#     # TODO: Activation.
#     fc2= tf.nn.tanh(fc2)
    fc2_drop = fc1_drop#tf.nn.dropout(fc2, keep_prob)

    # TODO: Layer 5: Fully Connected. Input = 84. Output = 10.
    fc3 = tf.add(
        tf.matmul(fc2_drop, weights['fully_connected_3']),
        biases['fully_connected_3'])
    # TODO: Activation.
    logits= tf.nn.tanh(fc3)
    return logits

# %%
def fully_connected(in_tensor,layers,keep_prob):
    mu = 0
    sigma = 0.1
    in_dim = np.product(in_tensor.get_shape().as_list()[1:])
    tensor_flatten = flatten(in_tensor)
    print(in_dim)
    for each in layers:
        weights = tf.Variable(tf.random_normal([in_dim, each],mu,sigma,dtype=tf.float32))
        bias =  tf.Variable(tf.zeros(each))

        fc1_drop = tf.nn.dropout(tensor_flatten, keep_prob)    
        fc2 = tf.add(
        tf.matmul(fc1_drop, weights),
        bias)
        # TODO: Activation.
        tensor_flatten = tf.nn.tanh(fc2)
        in_dim = each
        print(in_dim)
    
    return tensor_flatten
         

def LeNet_multi_batchnorm(x,keep_prob):    
    # Hyperparameters
    mu = 0
    sigma = 0.1
    layer_depth = {
    'layer_1': 9,
    'layer_2': 16,
    'fully_connected_1': 120,
#     'fully_connected_2': 84,
    'fully_connected_3': 43
    }
    
    input_layer = slim.conv2d(x,9,[5,5],activation_fn=None)
    
    input_layer_1 = slim.batch_norm(input_layer,activation_fn=None)
    input_layer_1 = tf.nn.relu(input_layer_1)
    layer_1 = maxpool(input_layer_1,k=2)
    
    input_layer_2 = slim.conv2d(layer_1,16,[5,5],activation_fn=None)
    input_layer_2 = slim.batch_norm(input_layer_2,activation_fn=None)
    input_layer_2 = tf.nn.relu(input_layer_2)
    layer_2 = maxpool(input_layer_2,k=2)
    
    fc1 = flatten(layer_2)
    fc1 = tf.concat(1,(fc1,flatten(layer_1)))
    
    
    logits = fully_connected(fc1,[140,56,43],keep_prob)
    return logits

# %%
def MyNet(x,keep_prob):    
    # Hyperparameters
    mu = 0
    sigma = 0.1
    layer_depth = {
    'layer_1': 9,
    'layer_2': 16,
    'fully_connected_1': 120,
    'fully_connected_2': 84,
    'fully_connected_3': 43
    }
    
    layer_depth_second = {
    'layer_1': 9,
    'layer_2': 16
        }
    weights_second = {
        'layer_1': tf.Variable(tf.random_normal([7, 7,1 , layer_depth_second['layer_1']], mean=0.0, stddev=1.0, dtype=tf.float32) ),
        'layer_2': tf.Variable(tf.random_normal(
                [7, 7, layer_depth_second['layer_1'], layer_depth_second['layer_2']],mu,sigma,dtype=tf.float32))
        }
    biases_second = {
        'layer_1': tf.Variable(tf.zeros(
                layer_depth_second['layer_1'])),
        'layer_2': tf.Variable(tf.zeros(
                layer_depth_second['layer_2']))
        }
    
    weights = {
        'layer_1': tf.Variable(tf.random_normal([5, 5,1 , layer_depth['layer_1']], mean=0.0, stddev=1.0, dtype=tf.float32) ),
        'layer_2': tf.Variable(tf.random_normal(
                [5, 5, layer_depth['layer_1'], layer_depth['layer_2']],mu,sigma,dtype=tf.float32)),
        'fully_connected_1':tf.Variable(tf.random_normal(
                [5*5*16+4*4*16, layer_depth['fully_connected_1']],mu,sigma,dtype=tf.float32)),
        'fully_connected_2':tf.Variable(tf.random_normal(
                [layer_depth['fully_connected_1'], layer_depth['fully_connected_2']],mu,sigma,dtype=tf.float32)),
        'fully_connected_3':tf.Variable(tf.random_normal(
                [layer_depth['fully_connected_2'], layer_depth['fully_connected_3']],mu,sigma,dtype=tf.float32))
    }
    biases = {
        'layer_1': tf.Variable(tf.zeros(
                layer_depth['layer_1'])),
        'layer_2': tf.Variable(tf.zeros(
                layer_depth['layer_2'])),
        'fully_connected_1':tf.Variable(tf.zeros( 
                layer_depth['fully_connected_1'])),
        'fully_connected_2':tf.Variable(tf.zeros( 
                layer_depth['fully_connected_2'])),
        'fully_connected_3':tf.Variable(tf.zeros( 
                layer_depth['fully_connected_3'])),
    }
    
    ####### SECOND #########
    second_layer_1 = conv2d(x,weights_second['layer_1'],biases_second['layer_1'],strides=1,padding='VALID')
    print(second_layer_1.get_shape())
    # TODO: Pooling. Input = 28x28x6. Output = 14x14x6.
    second_layer_1 = maxpool(second_layer_1,k=2)
    print(second_layer_1.get_shape())
    
    
    # TODO: Layer 2: Convolutional. Output = 10x10x16.
    
    # TODO: Activation.
    second_layer_2 = conv2d(second_layer_1,weights_second['layer_2'],biases_second['layer_2'],strides=1,padding='VALID')
    print(second_layer_2.get_shape())
    # TODO: Pooling. Input = 10x10x16. Output = 5x5x16.
    second_layer_2 = maxpool(second_layer_2,k=2)
    print(second_layer_2.get_shape())
    
    fc1_second = flatten(second_layer_2)
    
    ###################
    
    
    # TODO: Layer 1: Convolutional. Input = 32x32x3. Output = 28x28x6.
    # TODO: Activation.
    layer_1 = conv2d(x,weights['layer_1'],biases['layer_1'],strides=1,padding='VALID')
    print(layer_1.get_shape())
    # TODO: Pooling. Input = 28x28x6. Output = 14x14x6.
    layer_1 = maxpool(layer_1,k=2)
    print(layer_1.get_shape())
    
    
    # TODO: Layer 2: Convolutional. Output = 10x10x16.
    
    # TODO: Activation.
    layer_2 = conv2d(layer_1,weights['layer_2'],biases['layer_2'],strides=1,padding='VALID')
    print(layer_2.get_shape())
    # TODO: Pooling. Input = 10x10x16. Output = 5x5x16.
    layer_2 = maxpool(layer_2,k=2)
    print(layer_2.get_shape())
    
    
    # TODO: Flatten. Input = 5x5x16. Output = 400.
    fc1 = flatten(layer_2)
    fc1 = tf.concat(1,[fc1_second,fc1])#(,0))
    print(fc1.get_shape())
    
    
    fc1_drop = tf.nn.dropout(fc1, keep_prob)

    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.
    
    fc1 = tf.add(
        tf.matmul(fc1_drop, weights['fully_connected_1']),
        biases['fully_connected_1'])
    # TODO: Activation.
    fc1= tf.nn.tanh(fc1)
    
    
    fc1_drop = tf.nn.dropout(fc1, keep_prob)
    # TODO: Layer 4: Fully Connected. Input = 120. Output = 84.
    
    fc2 = tf.add(
        tf.matmul(fc1_drop, weights['fully_connected_2']),
        biases['fully_connected_2'])
    # TODO: Activation.
    fc2= tf.nn.tanh(fc2)
    fc2_drop = tf.nn.dropout(fc2, keep_prob)

    # TODO: Layer 5: Fully Connected. Input = 84. Output = 10.
    fc3 = tf.add(
        tf.matmul(fc2_drop, weights['fully_connected_3']),
        biases['fully_connected_3'])
    # TODO: Activation.
    logits= tf.nn.tanh(fc3)
    return logits

# %%
INPUT_DEPTH = 1
def MyNet2(x,keep_prob):
    print(x.get_shape())
    convolutions_list=[(5,7,1,1),(5,5,1,1),(5,3,1,1)] #filter_size, channels, stride, n_repeats

    #in_tensor = tf.reshape(self.state, [-1] + self.input_shape[1:])
    in_tensor = x
    for filter_size, num_outputs, stride, repeats in convolutions_list:
        for _ in range(repeats):
            in_tensor = tf.contrib.layers.convolution2d(in_tensor,
                num_outputs=num_outputs,
                kernel_size=filter_size,
                stride=stride,
                padding='VALID',
                rate=1,
                activation_fn=tf.nn.relu,
                trainable=True)
            print(in_tensor.get_shape())
                # TODO: parameterized pooling layers
        pool_out = tf.contrib.layers.max_pool2d(in_tensor,
            kernel_size=[2,2],
            stride=[1,1],
            padding='VALID')
        in_tensor = pool_out

    out_dim = np.product(in_tensor.get_shape().as_list()[1:])
    cnn_out = flatten(in_tensor)
    #fc_in_shape = cnn_out.get_shape()[1]
    fc1_drop_1 = tf.nn.dropout(cnn_out, keep_prob)
    mu = 0
    sigma = 0.1
    out_dim = np.product(in_tensor.get_shape().as_list()[1:])
    print(out_dim)
    fc_weights = tf.Variable(tf.truncated_normal(
            [out_dim, 43],mu,sigma,dtype=tf.float32))
    biases = tf.Variable(tf.zeros( 
            43))
    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.

    fc1_1 = tf.add(
                tf.matmul(fc1_drop_1, fc_weights)
                ,biases
                )
    # TODO: Activation.
    fc1_1= tf.nn.tanh(fc1_1)
        
    return fc1_1

# %%
tf.reset_default_graph()
x = tf.placeholder(tf.float32, (None, 32, 32, INPUT_DEPTH))
y = tf.placeholder(tf.int32, (None))
keep_prob = tf.placeholder(tf.float32)
one_hot_y = tf.one_hot(y, 43)

# %%
EPOCHS = 200
BATCH_SIZE = 1024

# %%
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#X_test_1,X_validation, y_test_1, y_validation = train_test_split(X_test, y_test, test_size=0.33, random_state=42)

# %%
rate = 0.001

logits = LeNet_multi(x,keep_prob)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
# Gradient clipping
gvs = optimizer.compute_gradients(loss_operation)
capped_gvs = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gvs]
optimizer.apply_gradients(capped_gvs)

training_operation = optimizer.minimize(loss_operation)
# Out:
# (?, 28, 28, 9)
# (?, 14, 14, 9)
# (?, 10, 10, 16)
# (?, 5, 5, 16)

# %%
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y,keep_prob:1.0})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

# %%
#model_file = "lenet_drop_v2"
import os
from imblearn.over_sampling import RandomOverSampler
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

#model_file = "./lenet_multi_final_v5"
model_file = "./lenet_multi_batch_norm_final_v5"
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    num_examples =len(X_train)#392090
    from pathlib import Path
    

    my_file = Path(model_file+".meta")
    if my_file.is_file():
        saver.restore(sess,model_file)
        print("Model restored...")
    print("Training...")
    print()
    ros = RandomOverSampler()
#     x_index = np.arange(0,len(y_train),1)
#     x_index_resampled, y_resampled = ros.fit_sample(np.expand_dims(x_index,axis=1), y_train)
#     x_in = np.squeeze(x_index_resampled)
#     X_resampled = X_train[x_in,:,:,]
#     X_train_1, y_train_1 = shuffle(X_resampled, y_resampled)
    X_train_1 = X_train
    y_train_1 = y_train
    print("Total "+str(len(y_train_1)))
    for i in range(EPOCHS):

        X_train, y_train = shuffle(X_train_1, y_train_1)
        acc = []
        ent = []
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            
            batch_x, batch_y = np.copy(X_train[offset:end]), np.copy(y_train[offset:end])
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y,keep_prob:0.5})
            training_accuracy = evaluate(batch_x, batch_y)
            mean_cross_entropy = sess.run(loss_operation, feed_dict={x: batch_x, y: batch_y,keep_prob:1.0})
            acc.append(training_accuracy)
            ent.append(mean_cross_entropy)
            
        validation_accuracy = evaluate(X_validation, y_validation)
        
        print("EPOCH {} ...".format(i+1))
        print("Training Accuracy = {:.3f}".format(np.mean(acc)))
        print("Cross entropy = {:.4f}".format(np.mean(ent)))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        
        if(i%10==0):
            saver.save(sess, model_file)
            print("Model saved")
        
    saver.save(sess, model_file)
    print("Model saved")
# Out:
# WARNING:tensorflow:From <ipython-input-40-9da3707cab21>:9 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Training...
#
# Total 274463
# EPOCH 1 ...
# Training Accuracy = 0.072
# Cross entropy = 3.4454
# Validation Accuracy = 0.069
# Model saved
# EPOCH 2 ...
# Training Accuracy = 0.096
# Cross entropy = 3.2286
# Validation Accuracy = 0.176
# EPOCH 3 ...
# Training Accuracy = 0.222
# Cross entropy = 2.9748
# Validation Accuracy = 0.338
# EPOCH 4 ...
# Training Accuracy = 0.322
# Cross entropy = 2.8009
# Validation Accuracy = 0.451
# EPOCH 5 ...
# Training Accuracy = 0.381
# Cross entropy = 2.7008
# Validation Accuracy = 0.506
# EPOCH 6 ...
# Training Accuracy = 0.410
# Cross entropy = 2.6407
# Validation Accuracy = 0.497
# EPOCH 7 ...
# Training Accuracy = 0.429
# Cross entropy = 2.5959
# Validation Accuracy = 0.521
# EPOCH 8 ...
# Training Accuracy = 0.441
# Cross entropy = 2.5648
# Validation Accuracy = 0.535
# EPOCH 9 ...
# Training Accuracy = 0.454
# Cross entropy = 2.5430
# Validation Accuracy = 0.546
# EPOCH 10 ...
# Training Accuracy = 0.461
# Cross entropy = 2.5189
# Validation Accuracy = 0.541
# EPOCH 11 ...
# Training Accuracy = 0.472
# Cross entropy = 2.5012
# Validation Accuracy = 0.546
# Model saved
# EPOCH 12 ...
# Training Accuracy = 0.480
# Cross entropy = 2.4862
# Validation Accuracy = 0.563
# EPOCH 13 ...
# Training Accuracy = 0.490
# Cross entropy = 2.4720
# Validation Accuracy = 0.549
# EPOCH 14 ...
# Training Accuracy = 0.499
# Cross entropy = 2.4587
# Validation Accuracy = 0.561
# EPOCH 15 ...
# Training Accuracy = 0.505
# Cross entropy = 2.4466
# Validation Accuracy = 0.566
# EPOCH 16 ...
# Training Accuracy = 0.512
# Cross entropy = 2.4340
# Validation Accuracy = 0.568
# EPOCH 17 ...
# Training Accuracy = 0.520
# Cross entropy = 2.4250
# Validation Accuracy = 0.573
# EPOCH 18 ...
# Training Accuracy = 0.526
# Cross entropy = 2.4142
# Validation Accuracy = 0.565
# EPOCH 19 ...
# Training Accuracy = 0.532
# Cross entropy = 2.4061
# Validation Accuracy = 0.581
# EPOCH 20 ...
# Training Accuracy = 0.538
# Cross entropy = 2.3990
# Validation Accuracy = 0.587
# EPOCH 21 ...
# Training Accuracy = 0.547
# Cross entropy = 2.3891
# Validation Accuracy = 0.591
# Model saved
# EPOCH 22 ...
# Training Accuracy = 0.551
# Cross entropy = 2.3825
# Validation Accuracy = 0.602
# EPOCH 23 ...
# Training Accuracy = 0.555
# Cross entropy = 2.3747
# Validation Accuracy = 0.588
# EPOCH 24 ...
# Training Accuracy = 0.561
# Cross entropy = 2.3673
# Validation Accuracy = 0.613
# EPOCH 25 ...
# Training Accuracy = 0.569
# Cross entropy = 2.3618
# Validation Accuracy = 0.613
# EPOCH 26 ...
# Training Accuracy = 0.574
# Cross entropy = 2.3550
# Validation Accuracy = 0.614
# EPOCH 27 ...
# Training Accuracy = 0.578
# Cross entropy = 2.3505
# Validation Accuracy = 0.617
# EPOCH 28 ...
# Training Accuracy = 0.583
# Cross entropy = 2.3462
# Validation Accuracy = 0.620
# EPOCH 29 ...
# Training Accuracy = 0.588
# Cross entropy = 2.3388
# Validation Accuracy = 0.608
# EPOCH 30 ...
# Training Accuracy = 0.593
# Cross entropy = 2.3321
# Validation Accuracy = 0.628
# EPOCH 31 ...
# Training Accuracy = 0.598
# Cross entropy = 2.3284
# Validation Accuracy = 0.635
# Model saved
# EPOCH 32 ...
# Training Accuracy = 0.599
# Cross entropy = 2.3248
# Validation Accuracy = 0.638
# EPOCH 33 ...
# Training Accuracy = 0.608
# Cross entropy = 2.3166
# Validation Accuracy = 0.645
# EPOCH 34 ...
# Training Accuracy = 0.613
# Cross entropy = 2.3121
# Validation Accuracy = 0.655
# EPOCH 35 ...
# Training Accuracy = 0.613
# Cross entropy = 2.3079
# Validation Accuracy = 0.627
# EPOCH 36 ...
# Training Accuracy = 0.617
# Cross entropy = 2.3054
# Validation Accuracy = 0.660
# EPOCH 37 ...
# Training Accuracy = 0.626
# Cross entropy = 2.3018
# Validation Accuracy = 0.668
# EPOCH 38 ...
# Training Accuracy = 0.625
# Cross entropy = 2.2980
# Validation Accuracy = 0.670
# EPOCH 39 ...
# Training Accuracy = 0.632
# Cross entropy = 2.2923
# Validation Accuracy = 0.670
# EPOCH 40 ...
# Training Accuracy = 0.636
# Cross entropy = 2.2894
# Validation Accuracy = 0.673
# EPOCH 41 ...
# Training Accuracy = 0.640
# Cross entropy = 2.2851
# Validation Accuracy = 0.655
# Model saved
# EPOCH 42 ...
# Training Accuracy = 0.641
# Cross entropy = 2.2815
# Validation Accuracy = 0.687
# EPOCH 43 ...
# Training Accuracy = 0.649
# Cross entropy = 2.2780
# Validation Accuracy = 0.684
# EPOCH 44 ...
# Training Accuracy = 0.653
# Cross entropy = 2.2742
# Validation Accuracy = 0.696
# EPOCH 45 ...
# Training Accuracy = 0.653
# Cross entropy = 2.2734
# Validation Accuracy = 0.690
# EPOCH 46 ...
# Training Accuracy = 0.658
# Cross entropy = 2.2684
# Validation Accuracy = 0.685
# EPOCH 47 ...
# Training Accuracy = 0.661
# Cross entropy = 2.2658
# Validation Accuracy = 0.694
# EPOCH 48 ...
# Training Accuracy = 0.665
# Cross entropy = 2.2614
# Validation Accuracy = 0.716
# EPOCH 49 ...
# Training Accuracy = 0.671
# Cross entropy = 2.2585
# Validation Accuracy = 0.706
# EPOCH 50 ...
# Training Accuracy = 0.674
# Cross entropy = 2.2568
# Validation Accuracy = 0.704
# EPOCH 51 ...
# Training Accuracy = 0.677
# Cross entropy = 2.2543
# Validation Accuracy = 0.706
# Model saved
# EPOCH 52 ...
# Training Accuracy = 0.680
# Cross entropy = 2.2509
# Validation Accuracy = 0.733
# EPOCH 53 ...
# Training Accuracy = 0.684
# Cross entropy = 2.2476
# Validation Accuracy = 0.722
# EPOCH 54 ...
# Training Accuracy = 0.684
# Cross entropy = 2.2450
# Validation Accuracy = 0.719
# EPOCH 55 ...
# Training Accuracy = 0.689
# Cross entropy = 2.2430
# Validation Accuracy = 0.730
# EPOCH 56 ...
# Training Accuracy = 0.690
# Cross entropy = 2.2391
# Validation Accuracy = 0.733
# EPOCH 57 ...
# Training Accuracy = 0.698
# Cross entropy = 2.2372
# Validation Accuracy = 0.731
# EPOCH 58 ...
# Training Accuracy = 0.698
# Cross entropy = 2.2350
# Validation Accuracy = 0.736
# EPOCH 59 ...
# Training Accuracy = 0.702
# Cross entropy = 2.2324
# Validation Accuracy = 0.736
# EPOCH 60 ...
# Training Accuracy = 0.704
# Cross entropy = 2.2309
# Validation Accuracy = 0.741
# EPOCH 61 ...
# Training Accuracy = 0.709
# Cross entropy = 2.2274
# Validation Accuracy = 0.735
# Model saved
# EPOCH 62 ...
# Training Accuracy = 0.708
# Cross entropy = 2.2252
# Validation Accuracy = 0.745
# EPOCH 63 ...
# Training Accuracy = 0.712
# Cross entropy = 2.2218
# Validation Accuracy = 0.758
# EPOCH 64 ...
# Training Accuracy = 0.715
# Cross entropy = 2.2205
# Validation Accuracy = 0.756
# EPOCH 65 ...
# Training Accuracy = 0.719
# Cross entropy = 2.2187
# Validation Accuracy = 0.754
# EPOCH 66 ...
# Training Accuracy = 0.721
# Cross entropy = 2.2172
# Validation Accuracy = 0.751
# EPOCH 67 ...
# Training Accuracy = 0.724
# Cross entropy = 2.2152
# Validation Accuracy = 0.755
# EPOCH 68 ...
# Training Accuracy = 0.724
# Cross entropy = 2.2117
# Validation Accuracy = 0.762
# EPOCH 69 ...
# Training Accuracy = 0.726
# Cross entropy = 2.2106
# Validation Accuracy = 0.765
# EPOCH 70 ...
# Training Accuracy = 0.733
# Cross entropy = 2.2057
# Validation Accuracy = 0.766
# EPOCH 71 ...
# Training Accuracy = 0.731
# Cross entropy = 2.2071
# Validation Accuracy = 0.764
# Model saved
# EPOCH 72 ...
# Training Accuracy = 0.732
# Cross entropy = 2.2050
# Validation Accuracy = 0.769
# EPOCH 73 ...
# Training Accuracy = 0.738
# Cross entropy = 2.2018
# Validation Accuracy = 0.763
# EPOCH 74 ...
# Training Accuracy = 0.738
# Cross entropy = 2.2008
# Validation Accuracy = 0.777
# EPOCH 75 ...
# Training Accuracy = 0.738
# Cross entropy = 2.1995
# Validation Accuracy = 0.781
# EPOCH 76 ...
# Training Accuracy = 0.739
# Cross entropy = 2.1965
# Validation Accuracy = 0.771
# EPOCH 77 ...
# Training Accuracy = 0.743
# Cross entropy = 2.1955
# Validation Accuracy = 0.776
# EPOCH 78 ...
# Training Accuracy = 0.745
# Cross entropy = 2.1921
# Validation Accuracy = 0.775
# EPOCH 79 ...
# Training Accuracy = 0.746
# Cross entropy = 2.1903
# Validation Accuracy = 0.780
# EPOCH 80 ...
# Training Accuracy = 0.744
# Cross entropy = 2.1953
# Validation Accuracy = 0.779
# EPOCH 81 ...
# Training Accuracy = 0.751
# Cross entropy = 2.1866
# Validation Accuracy = 0.782
# Model saved
# EPOCH 82 ...
# Training Accuracy = 0.752
# Cross entropy = 2.1856
# Validation Accuracy = 0.791
# EPOCH 83 ...
# Training Accuracy = 0.752
# Cross entropy = 2.1848
# Validation Accuracy = 0.785
# EPOCH 84 ...
# Training Accuracy = 0.755
# Cross entropy = 2.1816
# Validation Accuracy = 0.782
# EPOCH 85 ...
# Training Accuracy = 0.755
# Cross entropy = 2.1813
# Validation Accuracy = 0.786
# EPOCH 86 ...
# Training Accuracy = 0.758
# Cross entropy = 2.1789
# Validation Accuracy = 0.783
# EPOCH 87 ...
# Training Accuracy = 0.757
# Cross entropy = 2.1796
# Validation Accuracy = 0.786
# EPOCH 88 ...
# Training Accuracy = 0.761
# Cross entropy = 2.1766
# Validation Accuracy = 0.789
# EPOCH 89 ...
# Training Accuracy = 0.764
# Cross entropy = 2.1736
# Validation Accuracy = 0.793
# EPOCH 90 ...
# Training Accuracy = 0.765
# Cross entropy = 2.1739
# Validation Accuracy = 0.807
# EPOCH 91 ...
# Training Accuracy = 0.767
# Cross entropy = 2.1710
# Validation Accuracy = 0.792
# Model saved
# EPOCH 92 ...
# Training Accuracy = 0.769
# Cross entropy = 2.1712
# Validation Accuracy = 0.792
# EPOCH 93 ...
# Training Accuracy = 0.766
# Cross entropy = 2.1704
# Validation Accuracy = 0.803
# EPOCH 94 ...
# Training Accuracy = 0.770
# Cross entropy = 2.1689
# Validation Accuracy = 0.794
# EPOCH 95 ...
# Training Accuracy = 0.768
# Cross entropy = 2.1671
# Validation Accuracy = 0.795
# EPOCH 96 ...
# Training Accuracy = 0.771
# Cross entropy = 2.1651
# Validation Accuracy = 0.799
# EPOCH 97 ...
# Training Accuracy = 0.771
# Cross entropy = 2.1648
# Validation Accuracy = 0.797
# EPOCH 98 ...
# Training Accuracy = 0.772
# Cross entropy = 2.1621
# Validation Accuracy = 0.797
# EPOCH 99 ...
# Training Accuracy = 0.776
# Cross entropy = 2.1599
# Validation Accuracy = 0.801
# EPOCH 100 ...
# Training Accuracy = 0.776
# Cross entropy = 2.1595
# Validation Accuracy = 0.806
# EPOCH 101 ...
# Training Accuracy = 0.777
# Cross entropy = 2.1598
# Validation Accuracy = 0.807
# Model saved
# EPOCH 102 ...
# Training Accuracy = 0.779
# Cross entropy = 2.1590
# Validation Accuracy = 0.798
# EPOCH 103 ...
# Training Accuracy = 0.780
# Cross entropy = 2.1571
# Validation Accuracy = 0.804
# EPOCH 104 ...
# Training Accuracy = 0.780
# Cross entropy = 2.1554
# Validation Accuracy = 0.799
# EPOCH 105 ...
# Training Accuracy = 0.780
# Cross entropy = 2.1555
# Validation Accuracy = 0.810
# EPOCH 106 ...
# Training Accuracy = 0.782
# Cross entropy = 2.1549
# Validation Accuracy = 0.809
# EPOCH 107 ...
# Training Accuracy = 0.782
# Cross entropy = 2.1553
# Validation Accuracy = 0.806
# EPOCH 108 ...
# Training Accuracy = 0.784
# Cross entropy = 2.1518
# Validation Accuracy = 0.811
# EPOCH 109 ...
# Training Accuracy = 0.786
# Cross entropy = 2.1503
# Validation Accuracy = 0.820
# EPOCH 110 ...
# Training Accuracy = 0.787
# Cross entropy = 2.1495
# Validation Accuracy = 0.804
# EPOCH 111 ...
# Training Accuracy = 0.788
# Cross entropy = 2.1490
# Validation Accuracy = 0.814
# Model saved
# EPOCH 112 ...
# Training Accuracy = 0.790
# Cross entropy = 2.1462
# Validation Accuracy = 0.813
# EPOCH 113 ...
# Training Accuracy = 0.788
# Cross entropy = 2.1469
# Validation Accuracy = 0.804
# EPOCH 114 ...
# Training Accuracy = 0.790
# Cross entropy = 2.1442
# Validation Accuracy = 0.802
# EPOCH 115 ...
# Training Accuracy = 0.793
# Cross entropy = 2.1439
# Validation Accuracy = 0.812
# EPOCH 116 ...
# Training Accuracy = 0.789
# Cross entropy = 2.1437
# Validation Accuracy = 0.813
# EPOCH 117 ...
# Training Accuracy = 0.793
# Cross entropy = 2.1440
# Validation Accuracy = 0.823
# EPOCH 118 ...
# Training Accuracy = 0.792
# Cross entropy = 2.1417
# Validation Accuracy = 0.820
# EPOCH 119 ...
# Training Accuracy = 0.794
# Cross entropy = 2.1405
# Validation Accuracy = 0.818

# %%
#!pip install  imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl
# Collecting imbalanced-learn (from imblearn)
#   Downloading imbalanced-learn-0.2.1.tar.gz (90kB)
#     100% |████████████████████████████████| 92kB 460kB/s ta 0:00:01
# Requirement already satisfied: scipy>=0.17.0 in /opt/conda/lib/python3.5/site-packages (from imbalanced-learn->imblearn)
# Requirement already satisfied: numpy>=1.10.4 in /opt/conda/lib/python3.5/site-packages (from imbalanced-learn->imblearn)
# Requirement already satisfied: scikit-learn>=0.17.1 in /opt/conda/lib/python3.5/site-packages (from imbalanced-learn->imblearn)
# Building wheels for collected packages: imbalanced-learn
# done
#   Stored in directory: /root/.cache/pip/wheels/b8/20/bd/0b775f7e5d413ac72562b1a5126598bcb6e0eae10da659be9f
# Successfully built imbalanced-learn
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.2.1 imblearn-0.0

# %%
# new_training_file = "validation.p"
# new_train = {}
# new_train['features'] = X_validation
# new_train['labels'] = y_validation
# pickle.dump( new_train, open( new_training_file, "wb" ) )
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    num_examples =len(X_train)#392090
    from pathlib import Path
    

    my_file = Path(model_file)
    if my_file.is_file():
        saver.restore(sess,model_file)
        print("Model restored...")
    print(evaluate(X_test, y_test))
# Out:
# WARNING:tensorflow:From <ipython-input-9-14c7995175d5>:7 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-14c7995175d5> in <module>()
#      10
#      11
# ---> 12     my_file = Path(model_file)
#      13     if my_file.is_file():
#      14         saver.restore(sess,model_file)
#
# NameError: name 'model_file' is not defined

# %% [markdown]
# ### Question 1
#
# _Describe how you preprocessed the data. Why did you choose that technique?_

# %% [markdown]
# **Answer:**

# %%
### Generate data additional data (OPTIONAL!)
# With slight rotation only as flipping reverses the direction, so avoided some of the data preprocessing steps. 
# Contrast increase 
# 
### and split the data into training/validation/testing sets here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Question 2
#
# _Describe how you set up the training, validation and testing data for your model. **Optional**: If you generated additional data, how did you generate the data? Why did you generate the data? What are the differences in the new dataset (with generated data) from the original dataset?_

# %% [markdown]
# **Answer:**

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Question 3
#
# _What does your final architecture look like? (Type of model, layers, sizes, connectivity, etc.)  For reference on how to build a deep neural network using TensorFlow, see [Deep Neural Network in TensorFlow
# ](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/b516a270-8600-4f93-a0a3-20dfeabe5da6/concepts/83a3a2a2-a9bd-4b7b-95b0-eb924ab14432) from the classroom._

# %% [markdown]
# **Answer:**

# %%
### Train your model here.
### Feel free to use as many code cells as needed.

# Architecture diagram + Tensorflow graph.

# %% [markdown]
# ### Question 4
#
# _How did you train your model? (Type of optimizer, batch size, epochs, hyperparameters, etc.)_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 5
#
#
# _What approach did you take in coming up with a solution to this problem? It may have been a process of trial and error, in which case, outline the steps you took to get to the final solution and why you chose those steps. Perhaps your solution involved an already well known implementation or architecture. In this case, discuss why you think this is suitable for the current problem._

# %% [markdown]
# **Answer:**
# Things tried
# 1. Augment Data with -5 degree to 5 degree purterbation
# 2. Gray scale (Image convert)
# 3. Image Normalization
# 4. LeNet Architecture
# 5. Adding the drop out layer for the fully connected piece
# 6. Simpler model for Gray scale ( 94 % validation ). Removing the one layer of fully connected.
#
# Things to try
# 1. HSV/V value only
# 2. Zoom in Zoom out perturbation to data.
# 3. Multiple Conv layer before Pooling layer.
# 4. Regularizer/ Gradient clipping.
# 5. Batch Normalization

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# Take several pictures of traffic signs that you find on the web or around you (at least five), and run them through your classifier on your computer to produce example results. The classifier might not recognize some local signs but it could prove interesting nonetheless.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Question 6
#
# _Choose five candidate images of traffic signs and provide them in the report. Are there any particular qualities of the image(s) that might make classification difficult? It could be helpful to plot the images in the notebook._

# %% [markdown]
# **Answer:**

# %%
### Run the predictions here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Question 7
#
# _Is your model able to perform equally well on captured pictures when compared to testing on the dataset? The simplest way to do this check the accuracy of the predictions. For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate._
#
# _**NOTE:** You could check the accuracy manually by using `signnames.csv` (same directory). This file has a mapping from the class id (0-42) to the corresponding sign name. So, you could take the class id the model outputs, lookup the name in `signnames.csv` and see if it matches the sign from the image._

# %% [markdown]
# **Answer:**

# %%
### Visualize the softmax probabilities here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Question 8
#
# *Use the model's softmax probabilities to visualize the **certainty** of its predictions, [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here. Which predictions is the model certain of? Uncertain? If the model was incorrect in its initial prediction, does the correct prediction appear in the top k? (k should be 5 at most)*
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %% [markdown]
# **Answer:**

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
